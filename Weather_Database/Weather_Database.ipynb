# %%
# DELIVERABLE 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
#coordinates = list(lat_lngs)
#coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | inhambane
# Processing Record 2 of Set 1 | bereda
# Processing Record 3 of Set 1 | svetlogorsk
# Processing Record 4 of Set 1 | nelson bay
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 1 | mocajuba
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | nagornyy
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | husavik
# Processing Record 16 of Set 1 | pochutla
# Processing Record 17 of Set 1 | tanout
# Processing Record 18 of Set 1 | fare
# Processing Record 19 of Set 1 | belaya gora
# Processing Record 20 of Set 1 | balabac
# Processing Record 21 of Set 1 | abu samrah
# Processing Record 22 of Set 1 | cananea
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | piombino
# Processing Record 25 of Set 1 | krasnoselkup
# Processing Record 26 of Set 1 | deputatskiy
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | black river
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | port-de-paix
# City not found. Skipping...
# Processing Record 32 of Set 1 | sioux lookout
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | paamiut
# Processing Record 35 of Set 1 | csemo
# Processing Record 36 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | vestmanna
# Processing Record 40 of Set 1 | vostok
# Processing Record 41 of Set 1 | uribia
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | matay
# Processing Record 44 of Set 1 | preobrazheniye
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | tual
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | muborak
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | te anau
# Processing Record 3 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | port shepstone
# Processing Record 6 of Set 2 | dan khun thot
# Processing Record 7 of Set 2 | viedma
# Processing Record 8 of Set 2 | hervey bay
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | rio grande
# Processing Record 12 of Set 2 | broome
# Processing Record 13 of Set 2 | muros
# Processing Record 14 of Set 2 | omsukchan
# Processing Record 15 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 2 | constitucion
# Processing Record 17 of Set 2 | kamaishi
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | akyab
# Processing Record 20 of Set 2 | kachiry
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | peniche
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | carutapera
# Processing Record 35 of Set 2 | presidente medici
# Processing Record 36 of Set 2 | sola
# Processing Record 37 of Set 2 | mossendjo
# Processing Record 38 of Set 2 | rohnert park
# Processing Record 39 of Set 2 | souillac
# Processing Record 40 of Set 2 | sinazongwe
# Processing Record 41 of Set 2 | bilma
# Processing Record 42 of Set 2 | bandarbeyla
# Processing Record 43 of Set 2 | bafata
# Processing Record 44 of Set 2 | brae
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | northam
# Processing Record 48 of Set 2 | vestmannaeyjar
# Processing Record 49 of Set 2 | roros
# Processing Record 50 of Set 2 | birin
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | beringovskiy
# Processing Record 3 of Set 3 | bacalar
# Processing Record 4 of Set 3 | novopavlovka
# Processing Record 5 of Set 3 | princeton
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | estrela
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | kuching
# Processing Record 11 of Set 3 | gilleleje
# Processing Record 12 of Set 3 | pouembout
# Processing Record 13 of Set 3 | beloha
# Processing Record 14 of Set 3 | kemijarvi
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | pokhara
# Processing Record 19 of Set 3 | coquimbo
# Processing Record 20 of Set 3 | sulphur
# Processing Record 21 of Set 3 | nuuk
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | kysyl-syr
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | khromtau
# Processing Record 26 of Set 3 | saltpond
# Processing Record 27 of Set 3 | huilong
# Processing Record 28 of Set 3 | seydi
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | fort nelson
# Processing Record 31 of Set 3 | vanimo
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | hambantota
# Processing Record 35 of Set 3 | newport
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | kushmurun
# Processing Record 38 of Set 3 | port hardy
# Processing Record 39 of Set 3 | yerbogachen
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | sume
# Processing Record 42 of Set 3 | floresta
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | kuruman
# Processing Record 45 of Set 3 | oktyabrskoye
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | butaritari
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | bara
# Processing Record 3 of Set 4 | aksarka
# Processing Record 4 of Set 4 | hofn
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | mbaiki
# Processing Record 7 of Set 4 | nhulunbuy
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | umm lajj
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | sredec
# City not found. Skipping...
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | san felipe
# Processing Record 15 of Set 4 | chapais
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | touros
# Processing Record 19 of Set 4 | oudtshoorn
# Processing Record 20 of Set 4 | minjur
# Processing Record 21 of Set 4 | lagoa
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | tokur
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | beidao
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | arraial do cabo
# Processing Record 29 of Set 4 | cap malheureux
# Processing Record 30 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 4 | bukama
# Processing Record 32 of Set 4 | sete
# Processing Record 33 of Set 4 | hilo
# Processing Record 34 of Set 4 | la asuncion
# Processing Record 35 of Set 4 | sidney
# Processing Record 36 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 4 | fukue
# Processing Record 38 of Set 4 | atar
# Processing Record 39 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 40 of Set 4 | anapskaya
# Processing Record 41 of Set 4 | redmond
# Processing Record 42 of Set 4 | flin flon
# Processing Record 43 of Set 4 | brownwood
# Processing Record 44 of Set 4 | cape town
# Processing Record 45 of Set 4 | palu
# Processing Record 46 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 4 | skibbereen
# Processing Record 48 of Set 4 | galich
# Processing Record 49 of Set 4 | vao
# Processing Record 50 of Set 4 | joao pinheiro
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | sao pedro do sul
# Processing Record 3 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | xai-xai
# Processing Record 6 of Set 5 | qaanaaq
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | plettenberg bay
# Processing Record 9 of Set 5 | ponta delgada
# Processing Record 10 of Set 5 | puerto el triunfo
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | saint-jean-de-maurienne
# Processing Record 13 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | monrovia
# Processing Record 15 of Set 5 | saint-philippe
# Processing Record 16 of Set 5 | palmer
# Processing Record 17 of Set 5 | asilah
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | tasiilaq
# Processing Record 22 of Set 5 | mercedes
# Processing Record 23 of Set 5 | karangampel
# Processing Record 24 of Set 5 | fomboni
# Processing Record 25 of Set 5 | vung tau
# Processing Record 26 of Set 5 | sandpoint
# Processing Record 27 of Set 5 | aksu
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | sobolevo
# Processing Record 30 of Set 5 | lakhnadon
# Processing Record 31 of Set 5 | nehe
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | papar
# Processing Record 34 of Set 5 | dolores
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | mikumi
# Processing Record 38 of Set 5 | barrow
# Processing Record 39 of Set 5 | srednekolymsk
# Processing Record 40 of Set 5 | mar del plata
# Processing Record 41 of Set 5 | phan thiet
# Processing Record 42 of Set 5 | lhokseumawe
# Processing Record 43 of Set 5 | vanavara
# Processing Record 44 of Set 5 | antalaha
# Processing Record 45 of Set 5 | hasaki
# Processing Record 46 of Set 5 | krasnoarmeysk
# Processing Record 47 of Set 5 | duz
# City not found. Skipping...
# Processing Record 48 of Set 5 | bayevo
# Processing Record 49 of Set 5 | dunedin
# Processing Record 50 of Set 5 | hobyo
# Processing Record 1 of Set 6 | arlit
# Processing Record 2 of Set 6 | darien
# Processing Record 3 of Set 6 | komsomolskiy
# Processing Record 4 of Set 6 | raudeberg
# Processing Record 5 of Set 6 | antofagasta
# Processing Record 6 of Set 6 | sitka
# Processing Record 7 of Set 6 | siddipet
# Processing Record 8 of Set 6 | eureka
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | martapura
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | uruzgan
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | wukari
# Processing Record 15 of Set 6 | klichka
# Processing Record 16 of Set 6 | dabakala
# Processing Record 17 of Set 6 | avera
# Processing Record 18 of Set 6 | pangnirtung
# Processing Record 19 of Set 6 | anshun
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | severo-kurilsk
# Processing Record 22 of Set 6 | rakaia
# Processing Record 23 of Set 6 | mirnyy
# Processing Record 24 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | kjollefjord
# Processing Record 27 of Set 6 | daoukro
# Processing Record 28 of Set 6 | swan river
# Processing Record 29 of Set 6 | chuy
# Processing Record 30 of Set 6 | taoudenni
# Processing Record 31 of Set 6 | constantine
# Processing Record 32 of Set 6 | cabedelo
# Processing Record 33 of Set 6 | vardo
# Processing Record 34 of Set 6 | ambanja
# Processing Record 35 of Set 6 | morrovalle
# Processing Record 36 of Set 6 | russell
# Processing Record 37 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 6 | maniitsoq
# Processing Record 39 of Set 6 | mogadishu
# Processing Record 40 of Set 6 | grande prairie
# Processing Record 41 of Set 6 | arkhangelsk
# Processing Record 42 of Set 6 | saint-augustin
# Processing Record 43 of Set 6 | bud
# Processing Record 44 of Set 6 | lufilufi
# Processing Record 45 of Set 6 | pringsewu
# Processing Record 46 of Set 6 | kirakira
# Processing Record 47 of Set 6 | port elizabeth
# Processing Record 48 of Set 6 | tura
# Processing Record 49 of Set 6 | zemio
# Processing Record 50 of Set 6 | gunnedah
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | port blair
# Processing Record 3 of Set 7 | natchitoches
# Processing Record 4 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 7 | lahij
# Processing Record 6 of Set 7 | santa rosa
# Processing Record 7 of Set 7 | katsina
# Processing Record 8 of Set 7 | iskitim
# Processing Record 9 of Set 7 | ixtapa
# Processing Record 10 of Set 7 | saint-joseph
# Processing Record 11 of Set 7 | visby
# Processing Record 12 of Set 7 | ambam
# Processing Record 13 of Set 7 | fayaoue
# Processing Record 14 of Set 7 | mariestad
# Processing Record 15 of Set 7 | sinnamary
# Processing Record 16 of Set 7 | bethel
# Processing Record 17 of Set 7 | taltal
# Processing Record 18 of Set 7 | kyren
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | suoyarvi
# Processing Record 21 of Set 7 | cayenne
# Processing Record 22 of Set 7 | susuman
# Processing Record 23 of Set 7 | karratha
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | san francisco
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | corowa
# Processing Record 28 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 7 | kozhva
# Processing Record 30 of Set 7 | pucara
# Processing Record 31 of Set 7 | tadine
# Processing Record 32 of Set 7 | acapetahua
# Processing Record 33 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 7 | eirunepe
# Processing Record 35 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 36 of Set 7 | strezhevoy
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | nabire
# Processing Record 39 of Set 7 | port moresby
# Processing Record 40 of Set 7 | mandiana
# Processing Record 41 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 7 | kologriv
# Processing Record 43 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 7 | ovsyanka
# Processing Record 45 of Set 7 | uglich
# Processing Record 46 of Set 7 | samarai
# Processing Record 47 of Set 7 | betamcherla
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | alexandria
# Processing Record 50 of Set 7 | gurupi
# Processing Record 1 of Set 8 | kizilskoye
# Processing Record 2 of Set 8 | caravelas
# Processing Record 3 of Set 8 | yeppoon
# Processing Record 4 of Set 8 | darhan
# Processing Record 5 of Set 8 | panormos
# Processing Record 6 of Set 8 | havelock
# Processing Record 7 of Set 8 | lata
# Processing Record 8 of Set 8 | austin
# Processing Record 9 of Set 8 | phetchabun
# Processing Record 10 of Set 8 | kenai
# Processing Record 11 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 8 | lethem
# Processing Record 13 of Set 8 | acarau
# Processing Record 14 of Set 8 | porangatu
# Processing Record 15 of Set 8 | fuquay-varina
# Processing Record 16 of Set 8 | marsh harbour
# Processing Record 17 of Set 8 | guatire
# Processing Record 18 of Set 8 | bella union
# Processing Record 19 of Set 8 | moree
# Processing Record 20 of Set 8 | tessalit
# Processing Record 21 of Set 8 | baft
# Processing Record 22 of Set 8 | kerman
# Processing Record 23 of Set 8 | padang
# Processing Record 24 of Set 8 | chifeng
# Processing Record 25 of Set 8 | izhma
# Processing Record 26 of Set 8 | harper
# Processing Record 27 of Set 8 | pevek
# Processing Record 28 of Set 8 | zhuhai
# Processing Record 29 of Set 8 | bull savanna
# Processing Record 30 of Set 8 | erzin
# Processing Record 31 of Set 8 | lompoc
# Processing Record 32 of Set 8 | creston
# Processing Record 33 of Set 8 | macia
# Processing Record 34 of Set 8 | shingu
# Processing Record 35 of Set 8 | poum
# Processing Record 36 of Set 8 | seoul
# Processing Record 37 of Set 8 | sidi qasim
# City not found. Skipping...
# Processing Record 38 of Set 8 | caimito
# Processing Record 39 of Set 8 | methoni
# Processing Record 40 of Set 8 | san vicente
# Processing Record 41 of Set 8 | gold coast
# Processing Record 42 of Set 8 | merauke
# Processing Record 43 of Set 8 | cacoal
# Processing Record 44 of Set 8 | borogontsy
# Processing Record 45 of Set 8 | san carlos de bariloche
# Processing Record 46 of Set 8 | great falls
# Processing Record 47 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | karimpur
# Processing Record 50 of Set 8 | barcelona
# Processing Record 1 of Set 9 | dhidhdhoo
# Processing Record 2 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 9 | hay river
# Processing Record 4 of Set 9 | kavaratti
# Processing Record 5 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 9 | faya
# Processing Record 7 of Set 9 | porbandar
# Processing Record 8 of Set 9 | gashua
# Processing Record 9 of Set 9 | atasu
# Processing Record 10 of Set 9 | auki
# Processing Record 11 of Set 9 | skovorodino
# Processing Record 12 of Set 9 | astana
# Processing Record 13 of Set 9 | kiunga
# Processing Record 14 of Set 9 | barstow
# Processing Record 15 of Set 9 | frontera
# Processing Record 16 of Set 9 | kumi
# Processing Record 17 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 18 of Set 9 | hazaribag
# Processing Record 19 of Set 9 | lahaina
# Processing Record 20 of Set 9 | ambalavao
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | saskylakh
# Processing Record 23 of Set 9 | walvis bay
# Processing Record 24 of Set 9 | chanute
# Processing Record 25 of Set 9 | alofi
# Processing Record 26 of Set 9 | jyvaskyla
# Processing Record 27 of Set 9 | minudasht
# Processing Record 28 of Set 9 | koslan
# Processing Record 29 of Set 9 | pitimbu
# Processing Record 30 of Set 9 | andenes
# Processing Record 31 of Set 9 | general roca
# Processing Record 32 of Set 9 | wladyslawowo
# Processing Record 33 of Set 9 | krasnyy chikoy
# Processing Record 34 of Set 9 | jumla
# Processing Record 35 of Set 9 | zhigansk
# Processing Record 36 of Set 9 | pinotepa nacional
# Processing Record 37 of Set 9 | ahipara
# Processing Record 38 of Set 9 | amudat
# Processing Record 39 of Set 9 | benghazi
# Processing Record 40 of Set 9 | aras
# Processing Record 41 of Set 9 | asau
# Processing Record 42 of Set 9 | shizunai
# Processing Record 43 of Set 9 | mittagong
# Processing Record 44 of Set 9 | puerto palomas
# Processing Record 45 of Set 9 | nagato
# Processing Record 46 of Set 9 | fernie
# Processing Record 47 of Set 9 | tiznit
# Processing Record 48 of Set 9 | zacatepec
# Processing Record 49 of Set 9 | chimbote
# Processing Record 50 of Set 9 | waitati
# Processing Record 1 of Set 10 | katobu
# Processing Record 2 of Set 10 | khatanga
# Processing Record 3 of Set 10 | sabzevar
# Processing Record 4 of Set 10 | chiredzi
# Processing Record 5 of Set 10 | aberfeldy
# Processing Record 6 of Set 10 | mao
# Processing Record 7 of Set 10 | tocopilla
# Processing Record 8 of Set 10 | shambu
# Processing Record 9 of Set 10 | leshukonskoye
# Processing Record 10 of Set 10 | lazarev
# Processing Record 11 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 10 | kargasok
# Processing Record 13 of Set 10 | haines junction
# Processing Record 14 of Set 10 | ossora
# Processing Record 15 of Set 10 | yenagoa
# Processing Record 16 of Set 10 | ponnani
# Processing Record 17 of Set 10 | yumen
# Processing Record 18 of Set 10 | romny
# Processing Record 19 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 10 | yarada
# Processing Record 21 of Set 10 | labuan
# Processing Record 22 of Set 10 | bagdarin
# Processing Record 23 of Set 10 | vila velha
# Processing Record 24 of Set 10 | victoria point
# Processing Record 25 of Set 10 | mayo
# Processing Record 26 of Set 10 | saint-pierre
# Processing Record 27 of Set 10 | sorland
# Processing Record 28 of Set 10 | chicama
# Processing Record 29 of Set 10 | zyryanka
# Processing Record 30 of Set 10 | sao jose dos pinhais
# Processing Record 31 of Set 10 | high prairie
# Processing Record 32 of Set 10 | ilula
# Processing Record 33 of Set 10 | sabha
# Processing Record 34 of Set 10 | jiujiang
# Processing Record 35 of Set 10 | balkanabat
# Processing Record 36 of Set 10 | waddan
# Processing Record 37 of Set 10 | pitrufquen
# Processing Record 38 of Set 10 | chokurdakh
# Processing Record 39 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 10 | dubbo
# Processing Record 41 of Set 10 | raga
# Processing Record 42 of Set 10 | bat yam
# Processing Record 43 of Set 10 | passos
# Processing Record 44 of Set 10 | paso de carrasco
# Processing Record 45 of Set 10 | kruisfontein
# Processing Record 46 of Set 10 | ashdod
# Processing Record 47 of Set 10 | impfondo
# Processing Record 48 of Set 10 | chumikan
# Processing Record 49 of Set 10 | enschede
# Processing Record 50 of Set 10 | wewak
# Processing Record 1 of Set 11 | natal
# Processing Record 2 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 3 of Set 11 | thinadhoo
# Processing Record 4 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 11 | port hedland
# Processing Record 6 of Set 11 | la raya de santa maria
# Processing Record 7 of Set 11 | sao gabriel da cachoeira
# Processing Record 8 of Set 11 | belmonte
# Processing Record 9 of Set 11 | shahrud
# Processing Record 10 of Set 11 | san pedro
# Processing Record 11 of Set 11 | nerchinskiy zavod
# Processing Record 12 of Set 11 | nandi hills
# Processing Record 13 of Set 11 | whitehorse
# Processing Record 14 of Set 11 | ketchikan
# Processing Record 15 of Set 11 | puyang
# Processing Record 16 of Set 11 | batagay
# Processing Record 17 of Set 11 | leningradskiy
# Processing Record 18 of Set 11 | muncar
# Processing Record 19 of Set 11 | mucurapo
# Processing Record 20 of Set 11 | sajanan
# Processing Record 21 of Set 11 | genhe
# Processing Record 22 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 23 of Set 11 | newry
# Processing Record 24 of Set 11 | zheleznodorozhnyy
# Processing Record 25 of Set 11 | daud khel
# Processing Record 26 of Set 11 | nokaneng
# Processing Record 27 of Set 11 | puerto montt
# Processing Record 28 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 11 | japura
# Processing Record 30 of Set 11 | gusinoye ozero
# Processing Record 31 of Set 11 | talas
# Processing Record 32 of Set 11 | xinpu
# Processing Record 33 of Set 11 | groningen
# Processing Record 34 of Set 11 | janakpur road
# City not found. Skipping...
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | saint-francois
# Processing Record 37 of Set 11 | grindavik
# Processing Record 38 of Set 11 | chaman
# Processing Record 39 of Set 11 | tingi
# Processing Record 40 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 41 of Set 11 | solano
# Processing Record 42 of Set 11 | shamary
# Processing Record 43 of Set 11 | ust-kuyga
# Processing Record 44 of Set 11 | severnoye
# Processing Record 45 of Set 11 | grand-santi
# Processing Record 46 of Set 11 | nome
# Processing Record 47 of Set 11 | okhotsk
# Processing Record 48 of Set 11 | pryazha
# Processing Record 49 of Set 11 | saint-ambroise
# Processing Record 50 of Set 11 | twentynine palms
# Processing Record 1 of Set 12 | jiwani
# Processing Record 2 of Set 12 | boralday
# Processing Record 3 of Set 12 | acapulco
# Processing Record 4 of Set 12 | araouane
# Processing Record 5 of Set 12 | mangan
# Processing Record 6 of Set 12 | pandan
# Processing Record 7 of Set 12 | half moon bay
# Processing Record 8 of Set 12 | tulle
# Processing Record 9 of Set 12 | balsas
# Processing Record 10 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 12 | vrbno pod pradedem
# Processing Record 12 of Set 12 | bam
# Processing Record 13 of Set 12 | guerrero negro
# Processing Record 14 of Set 12 | longyearbyen
# Processing Record 15 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 12 | vilyuysk
# Processing Record 17 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 12 | sakakah
# Processing Record 19 of Set 12 | pohrebyshche
# Processing Record 20 of Set 12 | alyangula
# Processing Record 21 of Set 12 | zaliztsi
# Processing Record 22 of Set 12 | brokopondo
# Processing Record 23 of Set 12 | careiro da varzea
# Processing Record 24 of Set 12 | beyneu
# Processing Record 25 of Set 12 | sompeta
# Processing Record 26 of Set 12 | arawa
# Processing Record 27 of Set 12 | naze
# Processing Record 28 of Set 12 | moshkovo
# Processing Record 29 of Set 12 | mackay
# Processing Record 30 of Set 12 | coari
# Processing Record 31 of Set 12 | envira
# Processing Record 32 of Set 12 | igarka
# Processing Record 33 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 12 | shimoda
# Processing Record 35 of Set 12 | plouzane
# Processing Record 36 of Set 12 | solnechnyy
# Processing Record 37 of Set 12 | hailar
# Processing Record 38 of Set 12 | kidal
# Processing Record 39 of Set 12 | skjervoy
# Processing Record 40 of Set 12 | emerald
# Processing Record 41 of Set 12 | bangassou
# Processing Record 42 of Set 12 | luderitz
# Processing Record 43 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 12 | barranca
# Processing Record 45 of Set 12 | sansai
# City not found. Skipping...
# Processing Record 46 of Set 12 | chernyshevskiy
# Processing Record 47 of Set 12 | ostrovnoy
# Processing Record 48 of Set 12 | olafsvik
# Processing Record 49 of Set 12 | verkh-usugli
# Processing Record 50 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | handan
# Processing Record 2 of Set 13 | lagdo
# Processing Record 3 of Set 13 | trincomalee
# Processing Record 4 of Set 13 | post falls
# Processing Record 5 of Set 13 | jalu
# Processing Record 6 of Set 13 | atambua
# Processing Record 7 of Set 13 | rocha
# Processing Record 8 of Set 13 | planaltina
# Processing Record 9 of Set 13 | pozo colorado
# Processing Record 10 of Set 13 | parrita
# Processing Record 11 of Set 13 | uncia
# Processing Record 12 of Set 13 | madison
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 13 | henties bay
# Processing Record 16 of Set 13 | vaitape
# Processing Record 17 of Set 13 | fairbanks
# Processing Record 18 of Set 13 | puerto penasco
# Processing Record 19 of Set 13 | rovaniemi
# Processing Record 20 of Set 13 | xining
# Processing Record 21 of Set 13 | mbengwi
# Processing Record 22 of Set 13 | flinders
# Processing Record 23 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 24 of Set 13 | ahuimanu
# Processing Record 25 of Set 13 | barinitas
# Processing Record 26 of Set 13 | charlestown
# Processing Record 27 of Set 13 | north bend
# Processing Record 28 of Set 13 | roshchino
# Processing Record 29 of Set 13 | sao francisco de paula
# Processing Record 30 of Set 13 | cockburn town
# Processing Record 31 of Set 13 | isla mujeres
# Processing Record 32 of Set 13 | los llanos de aridane
# Processing Record 33 of Set 13 | yar-sale
# Processing Record 34 of Set 13 | djambala
# Processing Record 35 of Set 13 | axim
# Processing Record 36 of Set 13 | liuhe
# Processing Record 37 of Set 13 | madison heights
# Processing Record 38 of Set 13 | bako
# Processing Record 39 of Set 13 | fayetteville
# Processing Record 40 of Set 13 | znamenskoye
# Processing Record 41 of Set 13 | abonnema
# Processing Record 42 of Set 13 | semey
# Processing Record 43 of Set 13 | dosso
# Processing Record 44 of Set 13 | rawson
# Processing Record 45 of Set 13 | kapit
# Processing Record 46 of Set 13 | kalemie
# Processing Record 47 of Set 13 | buraydah
# Processing Record 48 of Set 13 | wyndham
# Processing Record 49 of Set 13 | ust-maya
# Processing Record 50 of Set 13 | nanortalik
# Processing Record 1 of Set 14 | hongjiang
# Processing Record 2 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 14 | siddharthanagar
# Processing Record 4 of Set 14 | noumea
# Processing Record 5 of Set 14 | morondava
# Processing Record 6 of Set 14 | zonguldak
# Processing Record 7 of Set 14 | tshikapa
# Processing Record 8 of Set 14 | bredy
# Processing Record 9 of Set 14 | tavda
# Processing Record 10 of Set 14 | khorramshahr
# Processing Record 11 of Set 14 | takoradi
# Processing Record 12 of Set 14 | kimbe
# Processing Record 13 of Set 14 | shache
# Processing Record 14 of Set 14 | dera din panah
# City not found. Skipping...
# Processing Record 15 of Set 14 | isangel
# Processing Record 16 of Set 14 | baykit
# Processing Record 17 of Set 14 | ekhabi
# Processing Record 18 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 14 | mount isa
# Processing Record 20 of Set 14 | moindou
# Processing Record 21 of Set 14 | altay
# Processing Record 22 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 14 | quelimane
# Processing Record 24 of Set 14 | manzanillo
# Processing Record 25 of Set 14 | kalininsk
# Processing Record 26 of Set 14 | bonavista
# Processing Record 27 of Set 14 | olovyannaya
# Processing Record 28 of Set 14 | teahupoo
# Processing Record 29 of Set 14 | coachella
# Processing Record 30 of Set 14 | hami
# Processing Record 31 of Set 14 | dalbandin
# Processing Record 32 of Set 14 | luena
# Processing Record 33 of Set 14 | kununurra
# Processing Record 34 of Set 14 | acandi
# Processing Record 35 of Set 14 | minna
# Processing Record 36 of Set 14 | boden
# Processing Record 37 of Set 14 | vila franca do campo
# Processing Record 38 of Set 14 | oranjemund
# Processing Record 39 of Set 14 | ginda
# Processing Record 40 of Set 14 | pointe michel
# Processing Record 41 of Set 14 | marystown
# Processing Record 42 of Set 14 | gizo
# Processing Record 43 of Set 14 | rio gallegos
# Processing Record 44 of Set 14 | pacific grove
# Processing Record 45 of Set 14 | kumluca
# Processing Record 46 of Set 14 | road town
# Processing Record 47 of Set 14 | ostersund
# Processing Record 48 of Set 14 | lavrentiya
# Processing Record 49 of Set 14 | nakamura
# Processing Record 50 of Set 14 | kimparana
# Processing Record 1 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 15 | akdepe
# Processing Record 3 of Set 15 | victor harbor
# Processing Record 4 of Set 15 | marzuq
# Processing Record 5 of Set 15 | zhanaozen
# Processing Record 6 of Set 15 | bauchi
# Processing Record 7 of Set 15 | evensk
# Processing Record 8 of Set 15 | krk
# Processing Record 9 of Set 15 | waingapu
# Processing Record 10 of Set 15 | orel-izumrud
# Processing Record 11 of Set 15 | aleksandrov gay
# Processing Record 12 of Set 15 | qujing
# Processing Record 13 of Set 15 | camana
# Processing Record 14 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 15 of Set 15 | barentu
# Processing Record 16 of Set 15 | rudbar
# Processing Record 17 of Set 15 | makinsk
# Processing Record 18 of Set 15 | ranong
# Processing Record 19 of Set 15 | shirokiy
# Processing Record 20 of Set 15 | makakilo city
# Processing Record 21 of Set 15 | penalva
# Processing Record 22 of Set 15 | bad orb
# Processing Record 23 of Set 15 | buala
# Processing Record 24 of Set 15 | elat
# Processing Record 25 of Set 15 | pekalongan
# Processing Record 26 of Set 15 | havre-saint-pierre
# Processing Record 27 of Set 15 | banda aceh
# Processing Record 28 of Set 15 | idah
# Processing Record 29 of Set 15 | qasigiannguit
# Processing Record 30 of Set 15 | makasar
# Processing Record 31 of Set 15 | riyadh
# Processing Record 32 of Set 15 | inuvik
# Processing Record 33 of Set 15 | abu dhabi
# Processing Record 34 of Set 15 | hermiston
# Processing Record 35 of Set 15 | sangod
# Processing Record 36 of Set 15 | taywarah
# Processing Record 37 of Set 15 | soyo
# Processing Record 38 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 15 | ishigaki
# Processing Record 40 of Set 15 | hualmay
# Processing Record 41 of Set 15 | adjumani
# Processing Record 42 of Set 15 | yuancheng
# Processing Record 43 of Set 15 | angoche
# Processing Record 44 of Set 15 | sterlitamak
# Processing Record 45 of Set 15 | mwingi
# Processing Record 46 of Set 15 | bustonkala
# City not found. Skipping...
# Processing Record 47 of Set 15 | salacgriva
# Processing Record 48 of Set 15 | muli
# Processing Record 49 of Set 15 | shibarghan
# City not found. Skipping...
# Processing Record 50 of Set 15 | khasan
# Processing Record 1 of Set 16 | sandnessjoen
# Processing Record 2 of Set 16 | khorixas
# Processing Record 3 of Set 16 | abeche
# Processing Record 4 of Set 16 | nakusp
# Processing Record 5 of Set 16 | danshui
# Processing Record 6 of Set 16 | varzea da palma
# Processing Record 7 of Set 16 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 16 | buin
# Processing Record 9 of Set 16 | niagara falls
# Processing Record 10 of Set 16 | linhares
# Processing Record 11 of Set 16 | uri
# Processing Record 12 of Set 16 | pemangkat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
## CREATE A DATAFRAME OF CITY WEATHER DATA
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Inhambane -23.8650   35.3833     58.98        94           0        0.00
# 1       Bereda  43.2686   -7.5406     63.41       100          94        4.52
# 2  Svetlogorsk  52.6333   29.7333     71.91        69          87        4.81
# 3   Nelson Bay -32.7167  152.1500     55.99        85          99        8.59
# 4  Port Alfred -33.5906   26.8910     61.52        79          27       26.62
# 5        Vaini -21.2000 -175.2000     68.16        94          40       13.80
# 6      Ushuaia -54.8000  -68.3000     46.06        57           0        6.91
# 7     Mocajuba  -2.5842  -49.5072     90.28        47          31        2.48
# 8   Bredasdorp -34.5322   20.0403     56.52        72          90        6.91
# 9     Nagornyy  52.7959   83.5498     70.95        59          13        4.45
#
#   Country Current Description
# 0      MZ           clear sky
# 1      ES     overcast clouds
# 2      BY     overcast clouds
# 3      AU     overcast clouds
# 4      ZA    scattered clouds
# 5      TO    scattered clouds
# 6      AR           clear sky
# 7      BR    scattered clouds
# 8      ZA     overcast clouds
# 9      RU          few clouds

# %%
# reorder the columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Inhambane      MZ -23.8650   35.3833     58.98        94           0
# 1       Bereda      ES  43.2686   -7.5406     63.41       100          94
# 2  Svetlogorsk      BY  52.6333   29.7333     71.91        69          87
# 3   Nelson Bay      AU -32.7167  152.1500     55.99        85          99
# 4  Port Alfred      ZA -33.5906   26.8910     61.52        79          27
#
#    Wind Speed Current Description
# 0        0.00           clear sky
# 1        4.52     overcast clouds
# 2        4.81     overcast clouds
# 3        8.59     overcast clouds
# 4       26.62    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
